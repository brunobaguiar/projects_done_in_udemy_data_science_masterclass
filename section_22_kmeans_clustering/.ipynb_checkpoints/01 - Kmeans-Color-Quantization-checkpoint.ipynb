# %% [markdown]
# # K Means Color Quantization

# %% [markdown]
# ### Imports

# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# ### The Image

# %%
image_as_array = mpimg.imread('../DATA/palm_trees.jpg')

# %%
image_as_array # RGB CODES FOR EACH PIXEL
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  99],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 107],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 115],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [ 10,  10,  12],
#         [ 10,  10,  12]]], dtype=uint8)

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(image_as_array)

# %% [markdown]
# ## Using Kmeans to Quantize Colors
#
# Quantizing colors means we'll reduce the number of unique colors here to K unique colors. Let's try just 6 colors!

# %%
image_as_array.shape
# (h,w,3 color channels)
# Out:
# (1401, 934, 3)

# %% [markdown]
# ### Convert from 3d to 2d
#
# Kmeans is designed to train on 2D data (data rows and feature columns), so we can reshape the above strip by using (h,w,c) ---> (h * w,c)

# %%
(h,w,c) = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
model
# Out:
# KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([3, 3, 3, ..., 1, 1, 1])

# %%
# THESE ARE THE 6 RGB COLOR CODES!
model.cluster_centers_
# Out:
# array([[ 67.48475702,  61.68701689,  62.10576254],
#        [  2.76432542,   2.58362743,   3.70929079],
#        [137.04613767, 143.84940738, 143.88729833],
#        [ 71.15927328, 109.30628948, 137.71848814],
#        [219.17406832, 135.32505676,  46.68774845],
#        [191.86002472, 154.52316779, 109.17412165]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[ 67,  62,  62],
#        [  3,   3,   4],
#        [137, 144, 144],
#        [ 71, 109, 138],
#        [219, 135,  47],
#        [192, 155, 109]])

# %%
quantized_image = np.reshape(rgb_codes[labels], (h, w, c))

# %%
quantized_image
# Out:
# array([[[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]]])

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(quantized_image)

# %% [markdown]
# ---
# ---
